# %%
from json import load

with open("return.json") as f:
    data = load(f)

print(data)
# Out:
# {'filename': 'input.png', 'images': ['...', '...', '...']}

# %%
import base64
from PIL import Image
import io
import matplotlib.pyplot as plt

# response is the JSON response from the server
for encoded_image in data["images"]:
    decoded_image = base64.b64decode(encoded_image)
    image = Image.open(io.BytesIO(decoded_image))
    plt.imshow(image)
    plt.show()

# %%
import base64
from PIL import Image
import io
import requests

response = requests.post("http://localhost:8000/uploadfile/", files={"file": ("input.png", open("/Users/tomburnip/Library/CloudStorage/OneDrive-Personal/Uni Stuff/Level 5/DSTP/CNN-Cropper/src/input.png", "rb"))})
# response is the JSON response from the server
for encoded_image in response.json()["images"]:
    decoded_image = base64.b64decode(encoded_image)
    image = Image.open(io.BytesIO(decoded_image))
    plt.imshow(image)
    plt.show()
